# %%
import pandas as pd

# %%
df = pd.read_table('data/POP_PLACES_20160601.txt',sep='|')

# %%
df
# Out:
#         ﻿FEATURE_ID                 FEATURE_NAME    FEATURE_CLASS STATE_ALPHA  \
# 0           1397658                        Ester  Populated Place          AK
# 1           1397685                   Two Rivers  Populated Place          AK
# 2           1397926                      Afognak  Populated Place          AK
# 3           1397967                    Aguikchuk  Populated Place          AK
# 4           1397989                    Aiaktalik  Populated Place          AK
# 5           1398007                       Akhiok  Populated Place          AK
# 6           1398011                     Akiachak  Populated Place          AK
# 7           1398012                        Akiak  Populated Place          AK
# 8           1398027                     Akulurak  Populated Place          AK
# 9           1398028                     Akulurak  Populated Place          AK
# 10          1398029                      Akumsuk  Populated Place          AK
# ...

# %%
reviews = pd.read_csv('data/final_critics.csv',sep='\t', usecols = ['publication','rating','gender'])

# %%
list_loc = list(df.FEATURE_NAME.values)
len(list_loc)
pattern = '|'.join(list_loc[500:600])

# %%
#reviews.publication.str.contains(pattern)
reviews[reviews['publication'].str.contains(pattern)]
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   from ipykernel import kernelapp as app
#                    publication  rating  gender
# 55               New York Post   fresh  female
# 136  New York Magazine/Vulture  rotten    male
# 184             New York Times   fresh     NaN
